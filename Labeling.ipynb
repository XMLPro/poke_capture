# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import os
import shutil

# %%
pokes = np.load("pokes.npy")

# %%
for i, poke in enumerate(pokes[640:660]):
    plt.imshow(poke[:,:,::-1])
    plt.figure()
# Out:
# /home/c0115334ef/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
plt.imshow(pokes[646])

# %%
temp = Image.fromarray(pokes[646])

# %%
temp.save("450-0.jpg")

# %%
pokesnumlist = list(np.load("pokesnumlist.npy"))

# %%
pokesnumlist.append(646)

# %%
np.save("pokesnumlist", pokesnumlist)

# %%
len(pokesnumlist)
# Out:
# 50

# %%
print(pokesnumlist)
# Out:
# [3, 76, 80, 86, 102, 112, 114, 115, 130, 138, 143, 158, 197, 213, 216, 218, 243, 270, 316, 325, 381, 419, 420, 434, 442, 459, 468, 518, 540, 557, 582, 612, 624, 639, 646, 649, 658, 683, 685, 686, 691, 692, 696, 716, 733, 753, 778, 792, 799, 829]

# %%
pokesnumlist.sort()

# %%
for i in pokesnumlist[40:60]:
    plt.imshow(pokes[i])
    plt.figure()

# %%
imgpath = os.listdir("./dataset/")

# %%
for i in range(len(imgpath)):
    imgpath[i], _ = os.path.splitext(imgpath[i])

# %%
imgpath
# Out:
# ['530-0',
#  '233-0',
#  '89-1',
#  '286-0',
#  '645-1',
#  '115-0',
#  '637-0',
#  '59-0',
#  '798-0',
#  '787-0',
#  '681-0',
#  '248-0',
#  '260-0',
#  '635-0',
#  '497-0',
#  '279-0',
#  '479-2',
#  '184-0',
#  '143-0',
#  '797-0',
#  '105-1',
#  '793-0',
#  '38-1',
#  '788-0',
#  '145-0',
#  '373-0',
#  '598-0',
#  '376-0',
#  '450-0',
#  '786-0',
#  '6-0',
#  '473-0',
#  '448-0',
#  '778-0',
#  '642-1',
#  '488-0',
#  '445-0',
#  '130-0',
#  '94-0',
#  '149-0',
#  '212-0',
#  '785-0',
#  '658-0',
#  '257-0',
#  '472-0',
#  '428-0',
#  '303-0',
#  '730-0',
#  '3-0',
#  '485-0']

# %%
for i in imgpath:
    os.mkdir('./dataset/'+i + '/')

# %%
for i in imgpath:
    shutil.move('./dataset/' + i + '.jpg', './dataset/' + i + '/')
